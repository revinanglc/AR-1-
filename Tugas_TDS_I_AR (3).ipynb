# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg

np.random.seed(10)

n = 100
phi1 = 0.2
mu = 1
sigma = 1

# Fungsi simulasi AR(1)
def simulate_ar1(phi, mu, n, sigma=1.0):

    Y = np.zeros(n)
    Y[0] = mu/(1-phi)

    et = np.random.normal(0, sigma, n)

    for t in range(1,n):
        Y[t] = mu + phi*Y[t-1] + et[t]

    return Y

# Generate data
Y = simulate_ar1(phi1, mu, n)

# Plot data
plt.plot(Y)
plt.title("Simulasi Data AR(1)")
plt.show()

# %%
model = AutoReg(Y, lags=1)
model_fit = model.fit()

print(model_fit.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:                      y   No. Observations:                  100
# Model:                     AutoReg(1)   Log Likelihood                -136.628
# Method:               Conditional MLE   S.D. of innovations              0.962
# Date:                Wed, 15 Apr 2026   AIC                            279.256
# Time:                        00:58:11   BIC                            287.042
# Sample:                             1   HQIC                           282.406
#                                   100
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1496      0.168      6.834      0.000       0.820       1.479
# y.L1           0.1389      0.102      1.368      0.171      -0.060       0.338
#                                     Roots
# ...

# %% [markdown]
# Diperoleh model AR(1)
#
# y_t=1.1496 + 0.1389𝑦_t-1+
# 𝜀
# _t
